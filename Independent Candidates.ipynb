# %%
import pandas as pd
files=[]

for file in os.listdir(os.getcwd()):
    if not os.path.isdir(file):
        filename=file.split('.')
        if filename[1]=='csv' and len (filename[0])==4:
            files.append(file)
        
files=sorted(files) 

#1989
df=pd.read_csv(files[8],usecols=['CANDIDATE','TERRITORY','CONSTITUENCY','PARTY','%'])
df1 = pd.DataFrame({'CANDIDATE':df['CANDIDATE'],'YEAR':files[8].split('.')[0],'STATE':df['TERRITORY'],'CONSTITUENCY':df['CONSTITUENCY'],'PARTY':df['PARTY'],'% of VOTES SECURED':df['%']})

#1991
df=pd.read_csv(files[9],usecols=['CANDIDATE','TERRITORY','CONSTITUENCY','PARTY','%'])
df2=pd.DataFrame({'CANDIDATE':df['CANDIDATE'],'YEAR':files[9].split('.')[0],'STATE':df['TERRITORY'],'CONSTITUENCY':df['CONSTITUENCY'],'PARTY':df['PARTY'],'% of VOTES SECURED':df['%']})
df1=df1.append(df2,ignore_index=True)

#1996
df=pd.read_csv(files[10],usecols=['CANDIDATE','TERRITORY','CONSTITUENCY','PARTY','%'])
df2=pd.DataFrame({'CANDIDATE':df['CANDIDATE'],'YEAR':files[10].split('.')[0],'STATE':df['TERRITORY'],'CONSTITUENCY':df['CONSTITUENCY'],'PARTY':df['PARTY'],'% of VOTES SECURED':df['%']})
df1=df1.append(df2,ignore_index=True)

#1998
df=pd.read_csv(files[11],usecols=['CANDIDATE','TERRITORY','CONSTITUENCY','PARTY','%'])
df2=pd.DataFrame({'CANDIDATE':df['CANDIDATE'],'YEAR':files[11].split('.')[0],'STATE':df['TERRITORY'],'CONSTITUENCY':df['CONSTITUENCY'],'PARTY':df['PARTY'],'% of VOTES SECURED':df['%']})
df1=df1.append(df2,ignore_index=True)

#1999
df=pd.read_csv(files[12],usecols=['CANDIDATE','TERRITORY','CONSTITUENCY','PARTY','%'])
df2=pd.DataFrame({'CANDIDATE':df['CANDIDATE'],'YEAR':files[12].split('.')[0],'STATE':df['TERRITORY'],'CONSTITUENCY':df['CONSTITUENCY'],'PARTY':df['PARTY'],'% of VOTES SECURED':df['%']})
df1=df1.append(df2,ignore_index=True)

#2004
df=pd.read_csv(files[13],usecols=['CANDIDATES','TERRITORY','CONSTITUENCY','PARTY','% OF TOTAL VOTES'])
df2=pd.DataFrame({'CANDIDATE':df['CANDIDATES'],'YEAR':files[13].split('.')[0],'STATE':df['TERRITORY'],'CONSTITUENCY':df['CONSTITUENCY'],'PARTY':df['PARTY'],'% of VOTES SECURED':df['% OF TOTAL VOTES']})
df1=df1.append(df2,ignore_index=True)

#2009
df=pd.read_csv(files[14],usecols=['CANDIDATE','STATE','CONSTITUENCY','PARTY','% OF TOTAL VOTES'])
df2=pd.DataFrame({'CANDIDATE':df['CANDIDATE'],'YEAR':files[14].split('.')[0],'STATE':df['STATE'],'CONSTITUENCY':df['CONSTITUENCY'],'PARTY':df['PARTY'],'% of VOTES SECURED':df['% OF TOTAL VOTES']})
df1=df1.append(df2,ignore_index=True)

#2014
df=pd.read_csv(files[15],usecols=['CANDIDATE','TERRITORY','CONSTITUENCY','PARTY','% OF TOTAL POLLED'])
df2=pd.DataFrame({'CANDIDATE':df['CANDIDATE'],'YEAR':files[15].split('.')[0],'STATE':df['TERRITORY'],'CONSTITUENCY':df['CONSTITUENCY'],'PARTY':df['PARTY'],'% of VOTES SECURED':df['% OF TOTAL POLLED']})
df1=df1.append(df2,ignore_index=True)

df1.to_csv('./Candidate.csv')
print ('File Updated')
# Out:
# File Updated

# %%
import pandas as pd

df=pd.read_csv('Candidate.csv')
Candidate_Count={}

cand=list(df['CANDIDATE'])
const=list(df['CONSTITUENCY'])

for name in cand:
    if name not in Candidate_Count:
        Candidate_Count[name]=[{df['CANDIDATE']}]
    else:
        Candidate_Count[name]+=1

l1=Candidate_Count.keys()
l2=Candidate_Count.values()
l=sorted(zip(l1,l2),key=lambda t:t[1],reverse=True)
print (l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-931af55d99dc> in <module>
#      10 for name in cand:
#      11     if name not in Candidate_Count:
# ---> 12         Candidate_Count[name]=[{df['CANDIDATE']}]
#      13     else:
#      14         Candidate_Count[name]+=1
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __hash__(self)
#    1885         raise TypeError(
#    1886             "{0!r} objects are mutable, thus they cannot be"
# -> 1887             " hashed".format(self.__class__.__name__)
#    1888         )
#    1889
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
import pandas as pd
from pprint import pprint

df=pd.read_csv('Candidate.csv')
Candidate_ConstituencyList={}
    
for index,row in df.iterrows():
    candidate=row['CANDIDATE']
    if candidate in Candidate_ConstituencyList:
        Candidate_ConstituencyList[candidate].append((row['YEAR'],row['CONSTITUENCY'].strip()))
    else:
        Candidate_ConstituencyList[candidate]=[(row['YEAR'],row['CONSTITUENCY'].strip())]

CandidateHistory={}
for key,value in Candidate_ConstituencyList.items():
    candi_year_const={}                                          
    for i in range(len(value)):
        year=value[i][0]
        constituency=value[i][1]
        if year not in candi_year_const:
            candi_year_const[year]=[constituency]
        else:
            candi_year_const[year].append(constituency)
                                                 
    CandidateHistory[key]=candi_year_const

pprint (CandidateHistory)
# Out:
# {' ABDUL AMIR AMIRO': {2014: ['CHANDNI CHOWK']},
#  ' DR. TARUN KUMAR': {2014: ['CHANDNI CHOWK']},
#  '"AIDS MAN" PRAKASH TATERAO LANDGE': {2004: ['NANDED']},
#  '"COMANDO" KAMAL KISHOR': {2014: ['Bahraich']},
#  '"SANDEEP SONI"': {2014: ['BALAGHAT']},
#  '"SUDAROLI" MURUGAN S.': {2009: ['Tirunelveli']},
#  '"YOGESH NANAJI SAMRITE"': {2014: ['BALAGHAT']},
#  "'AIDS MAN' PRAKASH": {2009: ['Nanded']},
#  '(DR) HARAK SINGH RAWAT': {2014: ['Garhwal']},
#  '(DR) RAKESH SINGH': {2014: ['Garhwal']},
#  '(DR.) SANJEEV KUMAR BALYAN': {2014: ['Muzaffarnagar']},
#  '(DR.)GIRIJA VYAS': {2009: ['Chittorgarh']},
#  '(KUPPAL)G.DEVADOSS': {2014: ['Chennai South']},
#  '(MAJ GEN (RETD.) ) BHUWAN CHANDRA KHANDURI (AVSM)': {2014: ['Garhwal']},
#  '(NAIK) DEVKATTE VENKATRAO NARSINGRAO': {2004: ['NANDED']},
#  'A ANSARI': {2004: ['CHIRAYINKIL']},
#  'A AZIZ': {1999: ['BALRAMPUR', 'BALRAMPUR']},
#  'A B A GHANI KHAN CHOUDHURY': {2004: ['MALDA']},
#  'A BIJU': {2014: ['Alathur']},
# ...
